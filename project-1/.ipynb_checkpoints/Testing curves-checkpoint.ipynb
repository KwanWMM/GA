# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def sigmoid(x):
    sigmoid_list=[]
    for item in x:
        sigmoid_list.append(1/(1+math.exp(-item)))
    
    return sigmoid_list

# %%
x = [num/50 for num in range(-200,200,)]
sig_list = sigmoid(x)
sig_list
# Out:
# [0.01798620996209156,
#  0.018342890697743287,
#  0.018706509954354602,
#  0.01907719731525816,
#  0.019455084568193035,
#  0.01984030573407751,
#  0.020232997095785403,
#  0.0206332972269062,
#  0.021041347020468282,
#  0.021457289717603523,
#  0.021881270936130476,
#  0.02231343869903224,
#  0.022753943462804,
#  0.023202938145644076,
#  0.023660578155461204,
#  0.024127021417669196,
#  0.024602428402739435,
#  0.025086962153479813,
#  0.025580788312007684,
#  0.026084075146382935,
#  0.026596993576865856,
#  0.02711971720176304,
#  0.027652422322823136,
#  0.02819528797014257,
#  0.02874849592653997,
#  0.02931223075135632,
#  0.029886679803636237,
#  0.030472033264644163,
#  0.03106848415966741,
#  0.0316762283790564,
#  0.032295464698450516,
#  0.032926394798136256,
#  0.03356922328148252,
#  0.03422415769239588,
#  0.03489140853173684,
#  0.03557118927263618,
#  0.03626371637464835,
#  0.03696920929667705,
#  0.037687890508605916,
#  0.038419985501565376,
# ...

# %%
plt.plot(x,sig_list)

# %%
sum(sig_list)
# Out:
# 199.51798620996215

# %%
def probability(num):
    return ((num/sum(sig_list))*0.6)

# %%
probability(0.01798620996209156)
# Out:
# 5.408898807698618e-05

# %%
prob_1 = [probability(num) for num in sig_list]

# %%
prob_1
# Out:
# [5.408898807698618e-05,
#  5.516161538972291e-05,
#  5.6255108553478065e-05,
#  5.73698572574274e-05,
#  5.8506257819942714e-05,
#  5.9664713275118836e-05,
#  6.0845633459311086e-05,
#  6.204943509762416e-05,
#  6.327654189028999e-05,
#  6.452738459886922e-05,
#  6.580240113220806e-05,
#  6.710203663207814e-05,
#  6.842674355842471e-05,
#  6.977698177414401e-05,
#  7.115321862930814e-05,
#  7.255592904475047e-05,
#  7.398559559492289e-05,
#  7.54427085899302e-05,
#  7.692776615664459e-05,
#  7.844127431879781e-05,
#  7.998374707594509e-05,
#  8.155570648119017e-05,
#  8.315768271755667e-05,
#  8.479021417288568e-05,
#  8.64538475131357e-05,
#  8.814913775395573e-05,
#  8.987664833039689e-05,
#  9.163695116462436e-05,
#  9.343062673148452e-05,
#  9.525826412177801e-05,
#  9.712046110308416e-05,
#  9.901782417797541e-05,
#  0.00010095096863945706,
#  0.00010292051862345941,
#  0.00010492710715820568,
#  0.00010697137621027194,
#  0.0001090539767271498,
#  0.00011117556867611708,
# ...

# %%
len(sig_list)
# Out:
# 400

# %%
y = [num/50 for num in range(-200,200,)]
rsig_list = r_sigmoid(y)

# %%
rsig_list
# Out:
# [1.0186856393377328,
#  1.0190631142916116,
#  1.0194482147453854,
#  1.0198410947443703,
#  1.0202419114458043,
#  1.0206508251817126,
#  1.0210679995230414,
#  1.02149360134509,
#  1.0219278008942616,
#  1.0223707718561656,
#  1.022822691425093,
#  1.023283740374897,
#  1.023754103131305,
#  1.024233967845691,
#  1.0247235264703394,
#  1.0252229748352273,
#  1.02573251272636,
#  1.0262523439656879,
#  1.0267826764926382,
#  1.0273237224472926,
#  1.027875698255247,
#  1.0284388247141845,
#  1.029013327082197,
#  1.029599435167892,
#  1.0301973834223186,
#  1.030807411032751,
#  1.0314297620183677,
#  1.0320646853278608,
#  1.0327124349390198,
#  1.0333732699603262,
#  1.0340474547345992,
#  1.0347352589447385,
#  1.0354369577215987,
#  1.0361528317540465,
#  1.03688316740124,
#  1.0376282568071762,
#  1.0383883980175521,
#  1.039163895098987,
#  1.0399550582606538,
#  1.0407622039783662,
#  1.041585655121173,
#  1.0424257410805113,
#  1.0432827979019659,
#  1.0441571684196929,
# ...

# %%
plt.plot(y,sigmoid(y)[::-1])

# %%
def probability_2(num):
    return ((num/sum(sigmoid(y)[::-1]))*0.4)

# %%
prob_2 = [probability_2(num) for num in sigmoid(y)[::-1]]

# %%
sum(prob_1)+sum(prob_2)
# Out:
# 0.999999999999999

# %%
x_axis = [num for num in range(800)]

# %%
len(x_axis)
# Out:
# 800

# %%
prob_combined = prob_1 + prob_2

# %%
len(prob_combined)
# Out:
# 800

# %%
plt.plot(x_axis,prob_combined)

# %%
def probability(num):
    return (num/sum(sig_list))

prob_1 = [probability(num) for num in sig_list]

def probability_2(num):
    return (num/sum(sig_list))

prob_2 = [probability_2(num) for num in sigmoid(y)[::-1]]

# %%
prob_1

# %%
def prob(num):
    return (num/sum(sig_list))

prob_1 = [prob(num) for num in sig_list]

def prob(num):
    return (num/sum(sig_list))

prob_2 = [prob(num) for num in sigmoid(y)[::-1]]

prob_c = prob_1+prob_2

# %%
plt.plot(x_axis,prob_c)

# %%
def sigmoid(x):
    sigmoid_list=[]
    for item in x:
        sigmoid_list.append(1/(1+math.exp(-item)))
    
    return sigmoid_list

# %%
x = [num/50 for num in range(-100,100,)]
sig_list = sigmoid(x)
sig_list
# Out:
# [0.11920292202211755,
#  0.12131883789173686,
#  0.12346704756522399,
#  0.12564785651534566,
#  0.12786156631908133,
#  0.13010847436299786,
#  0.13238887354206538,
#  0.13470305195202809,
#  0.13705129257545964,
#  0.13943387296165005,
#  0.14185106490048777,
#  0.14430313409051873,
#  0.14679033980138237,
#  0.14931293453084377,
#  0.15187116365665929,
#  0.1544652650835347,
#  0.15709546888545273,
#  0.15976199694366908,
#  0.1624650625806961,
#  0.1652048701906146,
#  0.16798161486607552,
#  0.17079548202237446,
#  0.17364664701900503,
#  0.1765352747791167,
#  0.17946151940732682,
#  0.18242552380635635,
#  0.18542741929298223,
#  0.18846732521381943,
#  0.19154534856146752,
#  0.19466158359157792,
#  0.19781611144141825,
#  0.20100899975052938,
#  0.20424030228409176,
#  0.20751005855963559,
#  0.21081829347774714,
#  0.2141650169574414,
#  0.2175502235768875,
#  0.22097389222018782,
#  0.22443598573092652,
#  0.22793645057321624,
#  0.23147521650098238,
# ...

# %%
plt.plot(x,sig_list)

# %%
sum(sig_list)
# Out:
# 99.61920292202213

# %%
def probability(num):
    return ((num/sum(sig_list+sigmoid(y))))

# %%
probability(sum(sig_list))
# Out:
# 0.2495960731422257

# %%
y = [num/50 for num in range(-300,300,)]

# %%
plt.plot(y,sigmoid(y)[::-1])

# %%
sum(sigmoid(y))
# Out:
# 299.50247262315685

# %%
prob_1 = [probability(num) for num in sig_list]

# %%
prob_2 = [probability(num)for num in sigmoid(y)[::-1]]

# %%
prob_3 = prob_1+prob_2

# %%
x_axis = [num for num in range(800)]

# %%
plt.plot(x_axis,prob_3)

# %%
x_row = [num for num in range(1,9)]
y_heights = [70,140,190,200,150,45,4,1]

plt.plot(x_row,y_heights)

# %%
np.linspace(1,70,10)
# Out:
# array([ 1.        ,  8.66666667, 16.33333333, 24.        , 31.66666667,
#        39.33333333, 47.        , 54.66666667, 62.33333333, 70.        ])

# %%
sum(np.linspace(140,190,10))
# Out:
# 1650.0

# %%
collect = [1+0.05*(num) for num in range(0,10)]

# %%
collect
# Out:
# [1.0, 1.05, 1.1, 1.15, 1.2, 1.25, 1.3, 1.35, 1.4, 1.45]

# %%
sum(collect)
# Out:
# 12.25

# %%
1.45/sum(collect)*4
# Out:
# 0.473469387755102

# %%
1/sum(collect)*1
# Out:
# 0.08163265306122448

# %%
#split into 10 parts:
#steps_10 = [1+0.005*(num) for num in range(0,10)]

    
def steps100(prob_subset):
    values_100=[]
    steps_10 = [1+0.035*(num) for num in range(0,10)]
    for num in steps_10:
        for element in steps_10:
            values_100.append(1/10*num/sum(steps_10)*prob_subset/800)
    return values_100

group_1 = steps100(1)
group_4 = steps100(4)
group_45 = steps100(45)
group_150 = steps100(150)
group_200 = steps100(200)
group_190 = steps100(190)
group_140 = steps100(140)
group_70 = steps100(70)

x_names = [i for i in range (1,801)]
prob_list = group_70+group_140+group_190+group_200[::-1]+group_150[::-1]+group_45[::-1]+group_4[::-1]+group_1[::-1]

plt.plot(x_names,prob_list)

# %%
#split into 10 parts:
#steps_10 = [1+0.005*(num) for num in range(0,10)]

    
def steps100(prob_subset):
    values_100=[]
    steps_10 = [1+0.035*(num) for num in range(0,10)]
    for num in steps_10:
        for element in steps_10:
            values_100.append(1/10*num/sum(steps_10)*prob_subset/800)
    return values_100

group_1 = steps100_2(1)

group_150 = steps100(150)
group_200 = steps100(200)
group_190 = steps100(190)
group_140 = steps100(140)

def steps100_2(prob_subset):
    values_100=[]
    steps_10 = [1+0.5*(num) for num in range(0,10)]
    for num in steps_10:
        for element in steps_10:
            values_100.append(1/10*num/sum(steps_10)*prob_subset/800)
    return values_100

group_70 = steps100_2(70)
group_4 = steps100_2(4)
group_45 = steps100_2(45)

x_names = [i for i in range (1,801)]
prob_list = group_70+group_140+group_190+group_200[::-1]+group_150[::-1]+group_45[::-1]+group_4[::-1]+group_1[::-1]

plt.plot(x_names,prob_list)

# %%
sum(prob_list)
# Out:
# 0.9999999999999991

# %%
prob_list[-1]
# Out:
# 8.639308855291577e-06

# %%
group_1 = steps100(1)
print(group_1[0])
print(group_1[-1])
# Out:
# 8.639308855291577e-06
# 1.1360691144708425e-05

# %%
group_4 = steps100(4)
print(group_4[0])
print(group_4[-1])
# Out:
# 0.03877847794474067
# 0.041221522055259335

# %%
group_45 = steps100(45)
print(group_45[0])
print(group_45[-1])
# Out:
# 0.43625787687833256
# 0.4637421231216675

# %%
group_150 = steps100(150)
print(group_150[0])
print(group_150[-1])
# Out:
# 1.4541929229277752
# 1.545807077072225

# %%
group_200 = steps100(200)
print(group_200[0])
print(group_200[-1])
# Out:
# 1.9389238972370337
# 2.061076102762967

# %%
group_190 = steps100(190)
print(group_190[0])
print(group_190[-1])
# Out:
# 1.841977702375182
# 1.9580222976248185

# %%
group_140 = steps100(140)
print(group_140[0])
print(group_140[-1])
# Out:
# 1.3572467280659235
# 1.4427532719340768

# %%
group_70 = steps100(70)
print(group_70[0])
print(group_70[-1])
# Out:
# 0.6786233640329618
# 0.7213766359670384

# %%
prob_list = group_70+group_140+group_190+group_200[::-1]+group_150[::-1]+group_45[::-1]+group_4[::-1]+group_1[::-1]

# %%
x_names = [i for i in range (1,801)]

# %%
plt.plot(x_names,prob_list)
