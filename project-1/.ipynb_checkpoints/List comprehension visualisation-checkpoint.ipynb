# %%
#Generate a list of strings from the raw data
raw_pd.splitlines()

#x is the entire list of strings
x = raw_pd.splitlines()

#generate a list of lists by interating through every list
[x[index_x].split(',') for index_x in range(len(x))]

#y is each individual list
y = x[index].split(,)

#Replace the double quotes in every line by iterating through every cell
[y[index_y].replace('""','') for index_y in range(len(y))]

#z is each individual element without double quotes inside
z = y[index_y].replace('""')

#convert each element to float if numeral, -1 if empty cell, leave as is if it is neither:
float(z) if z[0] in '0123456789' else -1 if z == '' else z

float(index_x) if index_y > 0 else float(z) if z[0] in '0123456789' else -1 if z == '' else z

##Putting everything back together: 
#zz is the converted element without double quotes
zz = float(z) if z[0] in '0123456789.' else -1 if z == '' else z

#Generate zz for the list (one pokemon) (from above, y is the individual list (one pokemon))
[zz for index_y in range(len(y))]

#yy is the converted pokemon stats in a list 
yy = [zz for index_y in range(len(y))]

#Generate a list for all pokemon 
[yy for index_x in range(len(x))]



#Substitute the values of yy, zz, z, y and x to (substitute in the reverse order they were create) get the nested list comprehension


Variables to substitute:
yy = [zz for index_y in range(len(y))]
zz = float(z) if z[0] in '0123456789.' else -1 if z == '' else z
z = y[index_y].replace('""')
y = x[index].split(,)
x = raw_pd.splitlines()

full list comprehension: [yy for index_x in range(len(x))]

#replace yy
[[zz for index_y in range(len(y))] for index_x in range(len(x))]

#replace zz
[[float(z) if z[0] in '0123456789.' else -1 if z == '' else z for index_y in range(len(y))] for index_x in range(len(x))]

#replace z:
[[float(y[index_y].replace('""')) if y[index_y].replace('""')[0] in '0123456789.' else -1 if y[index_y].replace('""') == '' else y[index_y].replace('""') for index_y in range(len(y))] for index_x in range(len(x))]

#replace y: **remember NOT TO replace the y in index_y
[[float(x[index].split(,)[index_y].replace('""')) if x[index].split(,)[index_y].replace('""')[0] in '0123456789.' else -1 if x[index].split(,)[index_y].replace('""') == '' else x[index].split(,)[index_y].replace('""') for index_y in range(len(x[index].split(,)))] for index_x in range(len(x))]

#replace x:
[[float(raw_pd.splitlines()[index].split(,)[index_y].replace('""')) if raw_pd.splitlines()[index].split(,)[index_y].replace('""')[0] in '0123456789.' else -1 if raw_pd.splitlines()[index].split(,)[index_y].replace('""') == '' else raw_pd.splitlines()[index].split(,)[index_y].replace('""') for index_y in range(len(raw_pd.splitlines()[index].split(,)))] for index_x in range(len(raw_pd.splitlines()))]
